# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaise152/Learning/blob/Learning/matplotlib/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

# %%
plt.style.use('seaborn')

# %% [markdown]
# These are the available styles in Matplotlib

# %% [markdown]
# # Introduction-To-Matplotlib

# %%
#from matplotlib import style
  
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
fig.savefig('my_figure.png')

# %%
# !ls -lh my_figure.png
# Out:
# -rw-r--r-- 1 root root 24K Aug 24 05:35 my_figure.png

# %%
Image('my_figure.png')  #from IPython.display import Image

# %%
plt.figure()  # create a plot figure
# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
plt.gcf()

# %%
plt.gca()

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# # Simple-Line-Plots

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

#The ax and fig create the container where we can plot the figure. ax are the axis. ax.plot will create the graph on which we plot the figure.

# %%
plt.plot(x, np.sin(x));

# %%
x = np.linspace(0, 10, 1000)
ax.plot(x, np.cos(x));

# %% [markdown]
# #### ploting multiple figure on single graph

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x))
ax.plot(x, np.cos(x))

# %% [markdown]
# #### Adjusting the Plot: Line Colors and Styles

# %%
plt.plot(x, np.sin(x - 0), color='blue', linestyle='solid')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g', linestyle='dashed')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75', linestyle='dashdot')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44', linestyle='dotted')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3), linestyle=':') # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse', linestyle='-.'); # all HTML color names supported

# %%
# linestyle and color codes can be combined into a single non-keyword argument to the plt.plot()
plt.plot(x, x + 0, '-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# #### Adjusting the Plot: Axes Limits

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x))
plt. xlim(-1,11)
plt.ylim(-1.5, 1.5);

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %%
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# #### Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ax.set() method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# # Simple Scatter Plots

# %% [markdown]
# #### Scatter Plots with plt.plot

# %%
x = np.linspace(0, 10, 50)
y = np.sin(x)

plt.plot(x, y, '-p', color='black');

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# Additional keyword arguments to plt.plot specify a wide range of properties of the lines and markers:

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=10, linewidth=2,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# #### Scatter Plots with plt.scatter

# %% [markdown]
# A second, more powerful method of creating scatter plots is the plt.scatter function, which can be used very similarly to the plt.plot function:

# %%
plt.scatter(x, y, marker='o');

# %% [markdown]
# The primary difference of plt.scatter from plt.plot is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.

# %% [markdown]
# This can be used for representing multi-dimensional data. X, Y, size of the point, Colour and brightness of the representation.

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.7,
            cmap='viridis')
plt.colorbar();  # show color scale

# %%
type(rng)
# Out:
# numpy.random.mtrand.RandomState

# %%
x
# Out:
# array([ 1.76405235,  0.40015721,  0.97873798,  2.2408932 ,  1.86755799,
#        -0.97727788,  0.95008842, -0.15135721, -0.10321885,  0.4105985 ,
#         0.14404357,  1.45427351,  0.76103773,  0.12167502,  0.44386323,
#         0.33367433,  1.49407907, -0.20515826,  0.3130677 , -0.85409574,
#        -2.55298982,  0.6536186 ,  0.8644362 , -0.74216502,  2.26975462,
#        -1.45436567,  0.04575852, -0.18718385,  1.53277921,  1.46935877,
#         0.15494743,  0.37816252, -0.88778575, -1.98079647, -0.34791215,
#         0.15634897,  1.23029068,  1.20237985, -0.38732682, -0.30230275,
#        -1.04855297, -1.42001794, -1.70627019,  1.9507754 , -0.50965218,
#        -0.4380743 , -1.25279536,  0.77749036, -1.61389785, -0.21274028,
#        -0.89546656,  0.3869025 , -0.51080514, -1.18063218, -0.02818223,
#         0.42833187,  0.06651722,  0.3024719 , -0.63432209, -0.36274117,
#        -0.67246045, -0.35955316, -0.81314628, -1.7262826 ,  0.17742614,
# ...

# %% [markdown]
# IRIS dataset

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
features = iris.data.T

# %%
max(features[2])
# Out:
# 6.9

# %%
plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
iris.feature_names[3]
# Out:
# 'petal width (cm)'

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# plt.plot can be noticeably more efficient than plt.scatter. The reason is that plt.scatter has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually. In plt.plot, on the other hand, the points are always essentially clones of each other, so the work of determining the appearance of the points is done only once for the entire set of data. For large datasets, the difference between these two can lead to vastly different performance, and for this reason, plt.plot should be preferred over plt.scatter for large datasets.
